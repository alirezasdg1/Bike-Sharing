# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
#show all columns
pd.set_option('display.max_columns', None)

# %%
df_weather = pd.read_csv('../Data-Bike-Sharing/datasets_20608_26794_Boston weather_clean.csv', sep=',')

# %%
df_weather.head(10)
# Out:
#    Year  Month  Day  High Temp (F)  Avg Temp (F)  Low Temp (F)  \
# 0  2008      1    1             40            34            28
# 1  2008      1    2             33            22            10
# 2  2008      1    3             14            11             7
# 3  2008      1    4             32            20             8
# 4  2008      1    5             42            35            27
# 5  2008      1    6             47            42            36
# 6  2008      1    7             55            45            35
# 7  2008      1    8             67            56            45
# 8  2008      1    9             62            54            46
# 9  2008      1   10             49            44            38
#
#    High Dew Point (F)  Avg Dew Point (F)  Low Dew Point (F)  \
# 0                  37                 31                 22
# 1                  28                 18                 -3
# 2                  -3                 -7                 -9
# 3                  13                  5                 -8
# 4                  26                 16                 12
# 5                  34                 30                 24
# 6                  43                 38                 32
# 7                  49                 45                 41
# 8                  52                 41                 17
# 9                  31                 25                 21
#
#    High Humidity (%)  Avg Humidity (%)  Low Humidity (%)  \
# 0                 92                79                66
# 1                 82                66                49
# 2                 60                50                40
# 3                 63                50                36
# 4                 64                47                30
# 5                 82                69                55
# 6                 92                77                61
# 7                 86                69                52
# 8                 90                57                24
# 9                 70                52                34
#
#    High Sea Level Press (in)  Avg Sea Level Press (in)  \
# 0                      30.18                     29.78
# 1                      30.20                     29.79
# 2                      30.62                     30.47
# 3                      30.60                     30.45
# 4                      30.38                     30.30
# 5                      30.22                     30.19
# 6                      30.21                     30.17
# 7                      30.13                     30.05
# 8                      29.93                     29.79
# 9                      30.12                     30.07
#
#    Low Sea Level Press (in)  High Visibility (mi)  Avg Visibility (mi)  \
# 0                     29.56                    10                    8
# 1                     29.55                    10                   10
# 2                     30.22                    10                   10
# 3                     30.37                    10                   10
# 4                     30.17                    10                   10
# 5                     30.15                    10                   10
# 6                     30.13                    10                    8
# 7                     29.93                    10                    9
# 8                     29.64                    10                   10
# 9                     29.92                    10                   10
#
#    Low Visibility (mi)  High Wind (mph)  Avg Wind (mph)  High Wind Gust (mph)  \
# 0                    1               23              10                    36
# 1                    9               28              15                    38
# 2                   10               25              17                    32
# 3                   10               23              12                    28
# 4                   10               16               9                    23
# 5                    9               15               7                    20
# 6                    5               18               7                    22
# 7                    7               18              12                    23
# 8                    9               29              18                    37
# 9                   10               16              11                    22
#
#    Snowfall (in)  Precip (in) Events
# 0           0.18         0.18   Both
# 1           0.00         0.00   Snow
# 2           0.00         0.00   None
# 3           0.00         0.00   None
# 4           0.00         0.00   None
# 5           0.00         0.00   None
# 6           0.00         0.00   None
# 7           0.00         0.00   None
# 8           0.00         0.00   Rain
# 9           0.00         0.00   None

# %%
df_Bike2017_1 = pd.read_csv('../Data-Bike-Sharing/201701-hubway-tripdata.csv', sep=',')
df_Bike2017_2 = pd.read_csv('../Data-Bike-Sharing/201702-hubway-tripdata.csv', sep=',')
df_Bike2017_3 = pd.read_csv('../Data-Bike-Sharing/201703-hubway-tripdata.csv', sep=',')
df_Bike2017_4 = pd.read_csv('../Data-Bike-Sharing/201704-hubway-tripdata.csv', sep=',')
df_Bike2017_5 = pd.read_csv('../Data-Bike-Sharing/201705-hubway-tripdata.csv', sep=',')
df_Bike2017_6 = pd.read_csv('../Data-Bike-Sharing/201706-hubway-tripdata.csv', sep=',')
df_Bike2017_7 = pd.read_csv('../Data-Bike-Sharing/201707-hubway-tripdata.csv', sep=',')
df_Bike2017_8 = pd.read_csv('../Data-Bike-Sharing/201708-hubway-tripdata.csv', sep=',')
df_Bike2017_9 = pd.read_csv('../Data-Bike-Sharing/201709-hubway-tripdata.csv', sep=',')
df_Bike2017_10 = pd.read_csv('../Data-Bike-Sharing/201710-hubway-tripdata.csv', sep=',')
df_Bike2017_11 = pd.read_csv('../Data-Bike-Sharing/201711-hubway-tripdata.csv', sep=',')
df_Bike2017_12 = pd.read_csv('../Data-Bike-Sharing/201712-hubway-tripdata.csv', sep=',')

# %%
df_Bike2017 = pd.concat([df_Bike2017_1, df_Bike2017_2,
                    df_Bike2017_3,df_Bike2017_4,
                    df_Bike2017_5, df_Bike2017_6,
                    df_Bike2017_7, df_Bike2017_8,
                    df_Bike2017_9, df_Bike2017_10,
                    df_Bike2017_11, df_Bike2017_12])
len(df_Bike2017)
# Out:
# 1313774

# %%
df_Bike2017.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           350  2017-01-01 00:06:58  2017-01-01 00:12:49                67
# 1           891  2017-01-01 00:13:16  2017-01-01 00:28:07                36
# 2          1672  2017-01-01 00:16:17  2017-01-01 00:44:10                36
# 3           747  2017-01-01 00:21:22  2017-01-01 00:33:50                46
# 4           621  2017-01-01 00:30:06  2017-01-01 00:40:28                10
#
#                          start station name  start station latitude  \
# 0              MIT at Mass Ave / Amherst St               42.358100
# 1  Boston Public Library - 700 Boylston St.               42.349673
# 2  Boston Public Library - 700 Boylston St.               42.349673
# 3                   Christian Science Plaza               42.343864
# 4             B.U. Central - 725 Comm. Ave.               42.350406
#
#    start station longitude  end station id  \
# 0               -71.093198             139
# 1               -71.077303              10
# 2               -71.077303               9
# 3               -71.085918              19
# 4               -71.108279               8
#
#                                 end station name  end station latitude  \
# 0                                      Dana Park             42.361780
# 1                  B.U. Central - 725 Comm. Ave.             42.350406
# 2                  Agganis Arena - 925 Comm Ave.             42.351246
# 3                        Buswell St. at Park Dr.             42.347241
# 4  Union Square - Brighton Ave. at Cambridge St.             42.353334
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -71.108100     644  Subscriber       1988       1
# 1             -71.108279     230  Subscriber       1983       1
# 2             -71.115639     980    Customer         \N       0
# 3             -71.105301    1834  Subscriber       1968       1
# 4             -71.137313     230  Subscriber       1983       1

# %%
df_Bike2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1313774 entries, 0 to 55071
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1313774 non-null  int64
#  1   starttime                1313774 non-null  object
#  2   stoptime                 1313774 non-null  object
#  3   start station id         1313774 non-null  int64
#  4   start station name       1313774 non-null  object
#  5   start station latitude   1313774 non-null  float64
#  6   start station longitude  1313774 non-null  float64
#  7   end station id           1313774 non-null  int64
#  8   end station name         1313774 non-null  object
#  9   end station latitude     1313774 non-null  float64
#  10  end station longitude    1313774 non-null  float64
#  11  bikeid                   1313774 non-null  int64
#  12  usertype                 1313774 non-null  object
#  13  birth year               1313774 non-null  object
#  14  gender                   1313774 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 160.4+ MB

# %%
df_Bike2017['Year'] = [datetime.strptime(d,'%Y-%m-%d %H:%M:%S').year for d in df_Bike2017['starttime']]
df_Bike2017['Month'] = [datetime.strptime(d,'%Y-%m-%d %H:%M:%S').month for d in df_Bike2017['starttime']]
df_Bike2017['Day'] = [datetime.strptime(d,'%Y-%m-%d %H:%M:%S').day for d in df_Bike2017['starttime']]
df_Bike2017['Weekday'] = [datetime.strptime(d,'%Y-%m-%d %H:%M:%S').weekday() for d in df_Bike2017['starttime']]
df_Bike2017['hour'] = [datetime.strptime(d,'%Y-%m-%d %H:%M:%S').hour for d in df_Bike2017['starttime']]

# %%
df_Bike2017.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           350  2017-01-01 00:06:58  2017-01-01 00:12:49                67
# 1           891  2017-01-01 00:13:16  2017-01-01 00:28:07                36
#
#                          start station name  start station latitude  \
# 0              MIT at Mass Ave / Amherst St               42.358100
# 1  Boston Public Library - 700 Boylston St.               42.349673
#
#    start station longitude  end station id               end station name  \
# 0               -71.093198             139                      Dana Park
# 1               -71.077303              10  B.U. Central - 725 Comm. Ave.
#
#    end station latitude  end station longitude  bikeid    usertype birth year  \
# 0             42.361780             -71.108100     644  Subscriber       1988
# 1             42.350406             -71.108279     230  Subscriber       1983
#
#    gender  Year  Month  Day  Weekday  hour
# 0       1  2017      1    1        6     0
# 1       1  2017      1    1        6     0

# %%
df_Bike_Weather = df_Bike2017.set_index(['Year','Month', 'Day']).join(df_weather.set_index(['Year','Month', 'Day']))

# %%
df_Bike_Weather.head()
# Out:
#                 tripduration            starttime             stoptime  \
# Year Month Day
# 2017 1     1             350  2017-01-01 00:06:58  2017-01-01 00:12:49
#            1             891  2017-01-01 00:13:16  2017-01-01 00:28:07
#            1            1672  2017-01-01 00:16:17  2017-01-01 00:44:10
#            1             747  2017-01-01 00:21:22  2017-01-01 00:33:50
#            1             621  2017-01-01 00:30:06  2017-01-01 00:40:28
#
#                 start station id                        start station name  \
# Year Month Day
# 2017 1     1                  67              MIT at Mass Ave / Amherst St
#            1                  36  Boston Public Library - 700 Boylston St.
#            1                  36  Boston Public Library - 700 Boylston St.
#            1                  46                   Christian Science Plaza
#            1                  10             B.U. Central - 725 Comm. Ave.
#
#                 start station latitude  start station longitude  \
# Year Month Day
# 2017 1     1                 42.358100               -71.093198
#            1                 42.349673               -71.077303
#            1                 42.349673               -71.077303
#            1                 42.343864               -71.085918
#            1                 42.350406               -71.108279
#
#                 end station id                               end station name  \
# Year Month Day
# 2017 1     1               139                                      Dana Park
#            1                10                  B.U. Central - 725 Comm. Ave.
#            1                 9                  Agganis Arena - 925 Comm Ave.
#            1                19                        Buswell St. at Park Dr.
#            1                 8  Union Square - Brighton Ave. at Cambridge St.
#
#                 end station latitude  end station longitude  bikeid  \
# Year Month Day
# 2017 1     1               42.361780             -71.108100     644
#            1               42.350406             -71.108279     230
#            1               42.351246             -71.115639     980
#            1               42.347241             -71.105301    1834
#            1               42.353334             -71.137313     230
#
#                   usertype birth year  gender  Weekday  hour  High Temp (F)  \
# Year Month Day
# 2017 1     1    Subscriber       1988       1        6     0             44
#            1    Subscriber       1983       1        6     0             44
#            1      Customer         \N       0        6     0             44
#            1    Subscriber       1968       1        6     0             44
#            1    Subscriber       1983       1        6     0             44
#
#                 Avg Temp (F)  Low Temp (F)  High Dew Point (F)  \
# Year Month Day
# 2017 1     1              40            33                  36
#            1              40            33                  36
#            1              40            33                  36
#            1              40            33                  36
#            1              40            33                  36
#
#                 Avg Dew Point (F)  Low Dew Point (F)  High Humidity (%)  \
# Year Month Day
# 2017 1     1                   27                 21                 93
#            1                   27                 21                 93
#            1                   27                 21                 93
#            1                   27                 21                 93
#            1                   27                 21                 93
#
#                 Avg Humidity (%)  Low Humidity (%)  High Sea Level Press (in)  \
# Year Month Day
# 2017 1     1                  64                30                      30.47
#            1                  64                30                      30.47
#            1                  64                30                      30.47
#            1                  64                30                      30.47
#            1                  64                30                      30.47
#
#                 Avg Sea Level Press (in)  Low Sea Level Press (in)  \
# Year Month Day
# 2017 1     1                       30.11                     29.87
#            1                       30.11                     29.87
#            1                       30.11                     29.87
#            1                       30.11                     29.87
#            1                       30.11                     29.87
#
#                 High Visibility (mi)  Avg Visibility (mi)  \
# Year Month Day
# 2017 1     1                      10                   10
#            1                      10                   10
#            1                      10                   10
#            1                      10                   10
#            1                      10                   10
#
#                 Low Visibility (mi)  High Wind (mph)  Avg Wind (mph)  \
# Year Month Day
# 2017 1     1                     10               23              15
#            1                     10               23              15
#            1                     10               23              15
#            1                     10               23              15
#            1                     10               23              15
#
#                 High Wind Gust (mph)  Snowfall (in)  Precip (in) Events
# Year Month Day
# 2017 1     1                      33            0.0         0.08   Rain
#            1                      33            0.0         0.08   Rain
#            1                      33            0.0         0.08   Rain
#            1                      33            0.0         0.08   Rain
#            1                      33            0.0         0.08   Rain

# %%
df_Bike_Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1313774 entries, (2017, 1, 1) to (2017, 12, 31)
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   tripduration               1313774 non-null  int64
#  1   starttime                  1313774 non-null  object
#  2   stoptime                   1313774 non-null  object
#  3   start station id           1313774 non-null  int64
#  4   start station name         1313774 non-null  object
#  5   start station latitude     1313774 non-null  float64
#  6   start station longitude    1313774 non-null  float64
#  7   end station id             1313774 non-null  int64
#  8   end station name           1313774 non-null  object
#  9   end station latitude       1313774 non-null  float64
#  10  end station longitude      1313774 non-null  float64
#  11  bikeid                     1313774 non-null  int64
#  12  usertype                   1313774 non-null  object
#  13  birth year                 1313774 non-null  object
#  14  gender                     1313774 non-null  int64
#  15  Weekday                    1313774 non-null  int64
#  16  hour                       1313774 non-null  int64
#  17  High Temp (F)              1313774 non-null  int64
#  18  Avg Temp (F)               1313774 non-null  int64
#  19  Low Temp (F)               1313774 non-null  int64
#  20  High Dew Point (F)         1313774 non-null  int64
#  21  Avg Dew Point (F)          1313774 non-null  int64
#  22  Low Dew Point (F)          1313774 non-null  int64
#  23  High Humidity (%)          1313774 non-null  int64
#  24  Avg Humidity (%)           1313774 non-null  int64
#  25  Low Humidity (%)           1313774 non-null  int64
#  26  High Sea Level Press (in)  1313774 non-null  float64
#  27  Avg Sea Level Press (in)   1313774 non-null  float64
#  28  Low Sea Level Press (in)   1313774 non-null  float64
#  29  High Visibility (mi)       1313774 non-null  int64
#  30  Avg Visibility (mi)        1313774 non-null  int64
#  31  Low Visibility (mi)        1313774 non-null  int64
#  32  High Wind (mph)            1313774 non-null  int64
#  33  Avg Wind (mph)             1313774 non-null  int64
#  34  High Wind Gust (mph)       1313774 non-null  int64
#  35  Snowfall (in)              1313774 non-null  float64
#  36  Precip (in)                1313774 non-null  float64
#  37  Events                     1313774 non-null  object
# dtypes: float64(9), int64(22), object(7)
# memory usage: 384.6+ MB

# %%
df_Holidays = pd.read_csv('../Data-Bike-Sharing/Holidays.csv', sep=',')

# %%
df_Holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      15 non-null     int64
#  1   Month     15 non-null     int64
#  2   Day       15 non-null     int64
#  3   Holidays  15 non-null     int64
# dtypes: int64(4)
# memory usage: 608.0 bytes

# %%
len(df_Bike_Weather)
# Out:
# 1313774

# %%
df_B_W_H = pd.merge(df_Bike_Weather, df_Holidays, how='left', on=['Year','Month', 'Day'])

# %%
df_B_W_H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1313774 entries, 0 to 1313773
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Year                       1313774 non-null  int64
#  1   Month                      1313774 non-null  int64
#  2   Day                        1313774 non-null  int64
#  3   tripduration               1313774 non-null  int64
#  4   starttime                  1313774 non-null  object
#  5   stoptime                   1313774 non-null  object
#  6   start station id           1313774 non-null  int64
#  7   start station name         1313774 non-null  object
#  8   start station latitude     1313774 non-null  float64
#  9   start station longitude    1313774 non-null  float64
#  10  end station id             1313774 non-null  int64
#  11  end station name           1313774 non-null  object
#  12  end station latitude       1313774 non-null  float64
#  13  end station longitude      1313774 non-null  float64
#  14  bikeid                     1313774 non-null  int64
#  15  usertype                   1313774 non-null  object
#  16  birth year                 1313774 non-null  object
#  17  gender                     1313774 non-null  int64
#  18  Weekday                    1313774 non-null  int64
#  19  hour                       1313774 non-null  int64
#  20  High Temp (F)              1313774 non-null  int64
#  21  Avg Temp (F)               1313774 non-null  int64
#  22  Low Temp (F)               1313774 non-null  int64
#  23  High Dew Point (F)         1313774 non-null  int64
#  24  Avg Dew Point (F)          1313774 non-null  int64
#  25  Low Dew Point (F)          1313774 non-null  int64
#  26  High Humidity (%)          1313774 non-null  int64
#  27  Avg Humidity (%)           1313774 non-null  int64
#  28  Low Humidity (%)           1313774 non-null  int64
#  29  High Sea Level Press (in)  1313774 non-null  float64
#  30  Avg Sea Level Press (in)   1313774 non-null  float64
#  31  Low Sea Level Press (in)   1313774 non-null  float64
#  32  High Visibility (mi)       1313774 non-null  int64
#  33  Avg Visibility (mi)        1313774 non-null  int64
#  34  Low Visibility (mi)        1313774 non-null  int64
#  35  High Wind (mph)            1313774 non-null  int64
#  36  Avg Wind (mph)             1313774 non-null  int64
#  37  High Wind Gust (mph)       1313774 non-null  int64
#  38  Snowfall (in)              1313774 non-null  float64
#  39  Precip (in)                1313774 non-null  float64
#  40  Events                     1313774 non-null  object
#  41  Holidays                   36313 non-null    float64
# dtypes: float64(10), int64(25), object(7)
# memory usage: 431.0+ MB

# %%
df_B_W_H = df_B_W_H.fillna(value={'Holidays': int(0)})

# %%
df_B_W_H ['Holidays'] = df_B_W_H ['Holidays'].astype(int)
df_B_W_H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1313774 entries, 0 to 1313773
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Year                       1313774 non-null  int64
#  1   Month                      1313774 non-null  int64
#  2   Day                        1313774 non-null  int64
#  3   tripduration               1313774 non-null  int64
#  4   starttime                  1313774 non-null  object
#  5   stoptime                   1313774 non-null  object
#  6   start station id           1313774 non-null  int64
#  7   start station name         1313774 non-null  object
#  8   start station latitude     1313774 non-null  float64
#  9   start station longitude    1313774 non-null  float64
#  10  end station id             1313774 non-null  int64
#  11  end station name           1313774 non-null  object
#  12  end station latitude       1313774 non-null  float64
#  13  end station longitude      1313774 non-null  float64
#  14  bikeid                     1313774 non-null  int64
#  15  usertype                   1313774 non-null  object
#  16  birth year                 1313774 non-null  object
#  17  gender                     1313774 non-null  int64
#  18  Weekday                    1313774 non-null  int64
#  19  hour                       1313774 non-null  int64
#  20  High Temp (F)              1313774 non-null  int64
#  21  Avg Temp (F)               1313774 non-null  int64
#  22  Low Temp (F)               1313774 non-null  int64
#  23  High Dew Point (F)         1313774 non-null  int64
#  24  Avg Dew Point (F)          1313774 non-null  int64
#  25  Low Dew Point (F)          1313774 non-null  int64
#  26  High Humidity (%)          1313774 non-null  int64
#  27  Avg Humidity (%)           1313774 non-null  int64
#  28  Low Humidity (%)           1313774 non-null  int64
#  29  High Sea Level Press (in)  1313774 non-null  float64
#  30  Avg Sea Level Press (in)   1313774 non-null  float64
#  31  Low Sea Level Press (in)   1313774 non-null  float64
#  32  High Visibility (mi)       1313774 non-null  int64
#  33  Avg Visibility (mi)        1313774 non-null  int64
#  34  Low Visibility (mi)        1313774 non-null  int64
#  35  High Wind (mph)            1313774 non-null  int64
#  36  Avg Wind (mph)             1313774 non-null  int64
#  37  High Wind Gust (mph)       1313774 non-null  int64
#  38  Snowfall (in)              1313774 non-null  float64
#  39  Precip (in)                1313774 non-null  float64
#  40  Events                     1313774 non-null  object
#  41  Holidays                   1313774 non-null  int64
# dtypes: float64(9), int64(26), object(7)
# memory usage: 431.0+ MB

# %%
df_B_W_H.head()
# Out:
#    Year  Month  Day  tripduration            starttime             stoptime  \
# 0  2017      1    1           350  2017-01-01 00:06:58  2017-01-01 00:12:49
# 1  2017      1    1           891  2017-01-01 00:13:16  2017-01-01 00:28:07
# 2  2017      1    1          1672  2017-01-01 00:16:17  2017-01-01 00:44:10
# 3  2017      1    1           747  2017-01-01 00:21:22  2017-01-01 00:33:50
# 4  2017      1    1           621  2017-01-01 00:30:06  2017-01-01 00:40:28
#
#    start station id                        start station name  \
# 0                67              MIT at Mass Ave / Amherst St
# 1                36  Boston Public Library - 700 Boylston St.
# 2                36  Boston Public Library - 700 Boylston St.
# 3                46                   Christian Science Plaza
# 4                10             B.U. Central - 725 Comm. Ave.
#
#    start station latitude  start station longitude  end station id  \
# 0               42.358100               -71.093198             139
# 1               42.349673               -71.077303              10
# 2               42.349673               -71.077303               9
# 3               42.343864               -71.085918              19
# 4               42.350406               -71.108279               8
#
#                                 end station name  end station latitude  \
# 0                                      Dana Park             42.361780
# 1                  B.U. Central - 725 Comm. Ave.             42.350406
# 2                  Agganis Arena - 925 Comm Ave.             42.351246
# 3                        Buswell St. at Park Dr.             42.347241
# 4  Union Square - Brighton Ave. at Cambridge St.             42.353334
#
#    end station longitude  bikeid    usertype birth year  gender  Weekday  \
# 0             -71.108100     644  Subscriber       1988       1        6
# 1             -71.108279     230  Subscriber       1983       1        6
# 2             -71.115639     980    Customer         \N       0        6
# 3             -71.105301    1834  Subscriber       1968       1        6
# 4             -71.137313     230  Subscriber       1983       1        6
#
#    hour  High Temp (F)  Avg Temp (F)  Low Temp (F)  High Dew Point (F)  \
# 0     0             44            40            33                  36
# 1     0             44            40            33                  36
# 2     0             44            40            33                  36
# 3     0             44            40            33                  36
# 4     0             44            40            33                  36
#
#    Avg Dew Point (F)  Low Dew Point (F)  High Humidity (%)  Avg Humidity (%)  \
# 0                 27                 21                 93                64
# 1                 27                 21                 93                64
# 2                 27                 21                 93                64
# 3                 27                 21                 93                64
# 4                 27                 21                 93                64
#
#    Low Humidity (%)  High Sea Level Press (in)  Avg Sea Level Press (in)  \
# 0                30                      30.47                     30.11
# 1                30                      30.47                     30.11
# 2                30                      30.47                     30.11
# 3                30                      30.47                     30.11
# 4                30                      30.47                     30.11
#
#    Low Sea Level Press (in)  High Visibility (mi)  Avg Visibility (mi)  \
# 0                     29.87                    10                   10
# 1                     29.87                    10                   10
# 2                     29.87                    10                   10
# 3                     29.87                    10                   10
# 4                     29.87                    10                   10
#
#    Low Visibility (mi)  High Wind (mph)  Avg Wind (mph)  High Wind Gust (mph)  \
# 0                   10               23              15                    33
# 1                   10               23              15                    33
# 2                   10               23              15                    33
# 3                   10               23              15                    33
# 4                   10               23              15                    33
#
#    Snowfall (in)  Precip (in) Events  Holidays
# 0            0.0         0.08   Rain         1
# 1            0.0         0.08   Rain         1
# 2            0.0         0.08   Rain         1
# 3            0.0         0.08   Rain         1
# 4            0.0         0.08   Rain         1

# %%
df_B_W_H['age'] = 2017 - pd.to_numeric(df_B_W_H['birth year'], errors = 'coerce')

# %%
df_B_W_H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1313774 entries, 0 to 1313773
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Year                       1313774 non-null  int64
#  1   Month                      1313774 non-null  int64
#  2   Day                        1313774 non-null  int64
#  3   tripduration               1313774 non-null  int64
#  4   starttime                  1313774 non-null  object
#  5   stoptime                   1313774 non-null  object
#  6   start station id           1313774 non-null  int64
#  7   start station name         1313774 non-null  object
#  8   start station latitude     1313774 non-null  float64
#  9   start station longitude    1313774 non-null  float64
#  10  end station id             1313774 non-null  int64
#  11  end station name           1313774 non-null  object
#  12  end station latitude       1313774 non-null  float64
#  13  end station longitude      1313774 non-null  float64
#  14  bikeid                     1313774 non-null  int64
#  15  usertype                   1313774 non-null  object
#  16  birth year                 1313774 non-null  object
#  17  gender                     1313774 non-null  int64
#  18  Weekday                    1313774 non-null  int64
#  19  hour                       1313774 non-null  int64
#  20  High Temp (F)              1313774 non-null  int64
#  21  Avg Temp (F)               1313774 non-null  int64
#  22  Low Temp (F)               1313774 non-null  int64
#  23  High Dew Point (F)         1313774 non-null  int64
#  24  Avg Dew Point (F)          1313774 non-null  int64
#  25  Low Dew Point (F)          1313774 non-null  int64
#  26  High Humidity (%)          1313774 non-null  int64
#  27  Avg Humidity (%)           1313774 non-null  int64
#  28  Low Humidity (%)           1313774 non-null  int64
#  29  High Sea Level Press (in)  1313774 non-null  float64
#  30  Avg Sea Level Press (in)   1313774 non-null  float64
#  31  Low Sea Level Press (in)   1313774 non-null  float64
#  32  High Visibility (mi)       1313774 non-null  int64
#  33  Avg Visibility (mi)        1313774 non-null  int64
#  34  Low Visibility (mi)        1313774 non-null  int64
#  35  High Wind (mph)            1313774 non-null  int64
#  36  Avg Wind (mph)             1313774 non-null  int64
#  37  High Wind Gust (mph)       1313774 non-null  int64
#  38  Snowfall (in)              1313774 non-null  float64
#  39  Precip (in)                1313774 non-null  float64
#  40  Events                     1313774 non-null  object
#  41  Holidays                   1313774 non-null  int64
#  42  age                        1102827 non-null  float64
# dtypes: float64(10), int64(26), object(7)
# memory usage: 441.0+ MB

# %%
mask0 = ((df_B_W_H['Month'] < 4))
mask1 = (df_B_W_H['Month'] >= 4) & (df_B_W_H['Month'] < 7)
mask2 = (df_B_W_H['Month'] >= 7) & (df_B_W_H['Month'] < 10)
mask3 = (df_B_W_H['Month'] >= 10)
df_B_W_H['season'] = np.select([mask0, mask1,mask2,mask3], 
                            [int(1), int(2), int(3), int(4)],default=np.nan)

# %% [markdown]
# ## Here, I am saving the processed dataset and re-loading data at this stage.

# %%
df_B_W_H.to_csv('../Data-Bike-Sharing/outputs/datasets_Bike_Weather_Holidays_raw.csv', sep=',')

# %%
df_B_W_H = pd.read_csv('../Data-Bike-Sharing/outputs/datasets_Bike_Weather_Holidays_raw.csv', sep=',')

# %% [markdown]
# ## Create different data tables

# %% [markdown]
# 1. Create data tables for comparing different days

# %%
df_B_W_H.head()
# Out:
#    Year  Month  Day  tripduration            starttime             stoptime  \
# 0  2017      1    1           350  2017-01-01 00:06:58  2017-01-01 00:12:49
# 1  2017      1    1           891  2017-01-01 00:13:16  2017-01-01 00:28:07
# 2  2017      1    1          1672  2017-01-01 00:16:17  2017-01-01 00:44:10
# 3  2017      1    1           747  2017-01-01 00:21:22  2017-01-01 00:33:50
# 4  2017      1    1           621  2017-01-01 00:30:06  2017-01-01 00:40:28
#
#    start station id                        start station name  \
# 0                67              MIT at Mass Ave / Amherst St
# 1                36  Boston Public Library - 700 Boylston St.
# 2                36  Boston Public Library - 700 Boylston St.
# 3                46                   Christian Science Plaza
# 4                10             B.U. Central - 725 Comm. Ave.
#
#    start station latitude  start station longitude  end station id  \
# 0               42.358100               -71.093198             139
# 1               42.349673               -71.077303              10
# 2               42.349673               -71.077303               9
# 3               42.343864               -71.085918              19
# 4               42.350406               -71.108279               8
#
#                                 end station name  end station latitude  \
# 0                                      Dana Park             42.361780
# 1                  B.U. Central - 725 Comm. Ave.             42.350406
# 2                  Agganis Arena - 925 Comm Ave.             42.351246
# 3                        Buswell St. at Park Dr.             42.347241
# 4  Union Square - Brighton Ave. at Cambridge St.             42.353334
#
#    end station longitude  bikeid    usertype birth year  gender  Weekday  \
# 0             -71.108100     644  Subscriber       1988       1        6
# 1             -71.108279     230  Subscriber       1983       1        6
# 2             -71.115639     980    Customer         \N       0        6
# 3             -71.105301    1834  Subscriber       1968       1        6
# 4             -71.137313     230  Subscriber       1983       1        6
#
#    hour  High Temp (F)  Avg Temp (F)  Low Temp (F)  High Dew Point (F)  \
# 0     0             44            40            33                  36
# 1     0             44            40            33                  36
# 2     0             44            40            33                  36
# 3     0             44            40            33                  36
# 4     0             44            40            33                  36
#
#    Avg Dew Point (F)  Low Dew Point (F)  High Humidity (%)  Avg Humidity (%)  \
# 0                 27                 21                 93                64
# 1                 27                 21                 93                64
# 2                 27                 21                 93                64
# 3                 27                 21                 93                64
# 4                 27                 21                 93                64
#
#    Low Humidity (%)  High Sea Level Press (in)  Avg Sea Level Press (in)  \
# 0                30                      30.47                     30.11
# 1                30                      30.47                     30.11
# 2                30                      30.47                     30.11
# 3                30                      30.47                     30.11
# 4                30                      30.47                     30.11
#
#    Low Sea Level Press (in)  High Visibility (mi)  Avg Visibility (mi)  \
# 0                     29.87                    10                   10
# 1                     29.87                    10                   10
# 2                     29.87                    10                   10
# 3                     29.87                    10                   10
# 4                     29.87                    10                   10
#
#    Low Visibility (mi)  High Wind (mph)  Avg Wind (mph)  High Wind Gust (mph)  \
# 0                   10               23              15                    33
# 1                   10               23              15                    33
# 2                   10               23              15                    33
# 3                   10               23              15                    33
# 4                   10               23              15                    33
#
#    Snowfall (in)  Precip (in) Events  Holidays   age  season
# 0            0.0         0.08   Rain         1  29.0     1.0
# 1            0.0         0.08   Rain         1  34.0     1.0
# 2            0.0         0.08   Rain         1   NaN     1.0
# 3            0.0         0.08   Rain         1  49.0     1.0
# 4            0.0         0.08   Rain         1  34.0     1.0

# %%
# df_BWH_day = df_B_W_H.groupby(['Year', 'Month','Day','Weekday','Avg Temp (F)','Avg Humidity (%)','Avg Visibility (mi)','Avg Wind (mph)','Events','Holidays','season','usertype','gender']).agg(Total_count_day=('starttime', 'count'), 
#                                mean_age=('age', 'mean'))
df_BWH_day_Gender = df_B_W_H.groupby(['Year', 'Month','Day','Weekday','Avg Temp (F)','Avg Humidity (%)','Avg Visibility (mi)','Avg Wind (mph)','Events','Holidays','season','gender','usertype']).agg(Total_count_day=('starttime', 'count')).unstack('gender')

# %%
pd.set_option('display.max_rows', None)
df_BWH_day_Gender.head(5)
# Out:
#                                                                                                                           Total_count_day  \
# gender                                                                                                                                  0
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season usertype
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0    Customer             102.0
#                                                                                                                Subscriber             2.0
#            2   0       34           72               10                  4              Rain   1        1.0    Customer             128.0
#                                                                                                                Subscriber             3.0
#            3   1       42           95               4                   16             Rain   0        1.0    Customer              20.0
#
#                                                                                                                                   \
# gender                                                                                                                         1
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season usertype
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0    Customer      NaN
#                                                                                                                Subscriber  292.0
#            2   0       34           72               10                  4              Rain   1        1.0    Customer      NaN
#                                                                                                                Subscriber  534.0
#            3   1       42           95               4                   16             Rain   0        1.0    Customer      NaN
#
#
# gender                                                                                                                         2
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season usertype
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0    Customer      NaN
#                                                                                                                Subscriber   85.0
#            2   0       34           72               10                  4              Rain   1        1.0    Customer      NaN
#                                                                                                                Subscriber  137.0
#            3   1       42           95               4                   16             Rain   0        1.0    Customer      NaN

# %% [markdown]
# Based on our data, it seems that casual users did not identify their gender. As such, when we want to test the gender effects, we have to discard causal customers from our data set.

# %%
df_BWH_day_CousType = df_B_W_H.groupby(['Year', 'Month','Day','Weekday','Avg Temp (F)','Avg Humidity (%)','Avg Visibility (mi)','Avg Wind (mph)','Events','Holidays','season','usertype']).agg(Total_count_day=('starttime', 'count')).unstack()

# %%
df_BWH_day_CousType.head(5)
# Out:
#                                                                                                                Total_count_day  \
# usertype                                                                                                              Customer
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0              102.0
#            2   0       34           72               10                  4              Rain   1        1.0              128.0
#            3   1       42           95               4                   16             Rain   0        1.0               20.0
#            4   2       42           84               9                   12             Both   0        1.0              103.0
#            5   3       30           45               10                  16             None   0        1.0               57.0
#
#
# usertype                                                                                                       Subscriber
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0         379.0
#            2   0       34           72               10                  4              Rain   1        1.0         674.0
#            3   1       42           95               4                   16             Rain   0        1.0         631.0
#            4   2       42           84               9                   12             Both   0        1.0        1431.0
#            5   3       30           45               10                  16             None   0        1.0        1273.0

# %%
df_BWH_day_Total = df_B_W_H.groupby(['Year', 'Month','Day','Weekday','Avg Temp (F)','Avg Humidity (%)','Avg Visibility (mi)','Avg Wind (mph)','Events','Holidays','season']).agg(Total_count_day=('starttime', 'count'))

# %%
df_BWH_day_Total.head(10)
# Out:
#                                                                                                                 Total_count_day
# Year Month Day Weekday Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season
# 2017 1     1   6       40           64               10                  15             Rain   1        1.0                 481
#            2   0       34           72               10                  4              Rain   1        1.0                 802
#            3   1       42           95               4                   16             Rain   0        1.0                 651
#            4   2       42           84               9                   12             Both   0        1.0                1534
#            5   3       30           45               10                  16             None   0        1.0                1330
#            6   4       28           65               8                   7              Snow   0        1.0                 836
#            7   5       20           75               4                   13             Snow   0        1.0                 106
#            8   6       16           55               10                  14             Snow   0        1.0                 111
#            9   0       14           52               10                  11             None   0        1.0                 392
#            10  1       28           79               9                   9              Rain   0        1.0                 469

# %%
df_BWH_hour_Total = df_B_W_H.groupby(['Year', 'Month','Day','Weekday','hour','Avg Temp (F)','Avg Humidity (%)','Avg Visibility (mi)','Avg Wind (mph)','Events','Holidays','season']).agg(Total_count_hour=('starttime', 'count'))

# %%
df_BWH_hour_Total.head(50)
# Out:
#                                                                                                                      Total_count_hour
# Year Month Day Weekday hour Avg Temp (F) Avg Humidity (%) Avg Visibility (mi) Avg Wind (mph) Events Holidays season
# 2017 1     1   6       0    40           64               10                  15             Rain   1        1.0                   13
#                        1    40           64               10                  15             Rain   1        1.0                    7
#                        2    40           64               10                  15             Rain   1        1.0                    4
#                        3    40           64               10                  15             Rain   1        1.0                    2
#                        4    40           64               10                  15             Rain   1        1.0                    6
#                        5    40           64               10                  15             Rain   1        1.0                    1
#                        6    40           64               10                  15             Rain   1        1.0                    7
#                        7    40           64               10                  15             Rain   1        1.0                    2
#                        8    40           64               10                  15             Rain   1        1.0                    5
#                        9    40           64               10                  15             Rain   1        1.0                   13
#                        10   40           64               10                  15             Rain   1        1.0                   20
#                        11   40           64               10                  15             Rain   1        1.0                   37
#                        12   40           64               10                  15             Rain   1        1.0                   54
#                        13   40           64               10                  15             Rain   1        1.0                   51
#                        14   40           64               10                  15             Rain   1        1.0                   45
#                        15   40           64               10                  15             Rain   1        1.0                   37
#                        16   40           64               10                  15             Rain   1        1.0                   45
#                        17   40           64               10                  15             Rain   1        1.0                   34
#                        18   40           64               10                  15             Rain   1        1.0                   32
#                        19   40           64               10                  15             Rain   1        1.0                   19
#                        20   40           64               10                  15             Rain   1        1.0                   13
#                        21   40           64               10                  15             Rain   1        1.0                   15
#                        22   40           64               10                  15             Rain   1        1.0                   15
#                        23   40           64               10                  15             Rain   1        1.0                    4
#            2   0       0    34           72               10                  4              Rain   1        1.0                    9
#                        1    34           72               10                  4              Rain   1        1.0                    2
#                        2    34           72               10                  4              Rain   1        1.0                    2
#                        3    34           72               10                  4              Rain   1        1.0                    1
#                        5    34           72               10                  4              Rain   1        1.0                    2
#                        6    34           72               10                  4              Rain   1        1.0                    5
#                        7    34           72               10                  4              Rain   1        1.0                   15
#                        8    34           72               10                  4              Rain   1        1.0                   31
#                        9    34           72               10                  4              Rain   1        1.0                   45
#                        10   34           72               10                  4              Rain   1        1.0                   32
#                        11   34           72               10                  4              Rain   1        1.0                   61
#                        12   34           72               10                  4              Rain   1        1.0                   70
#                        13   34           72               10                  4              Rain   1        1.0                   77
#                        14   34           72               10                  4              Rain   1        1.0                   71
#                        15   34           72               10                  4              Rain   1        1.0                   82
#                        16   34           72               10                  4              Rain   1        1.0                   74
#                        17   34           72               10                  4              Rain   1        1.0                   53
#                        18   34           72               10                  4              Rain   1        1.0                   42
#                        19   34           72               10                  4              Rain   1        1.0                   47
#                        20   34           72               10                  4              Rain   1        1.0                   45
#                        21   34           72               10                  4              Rain   1        1.0                   11
#                        22   34           72               10                  4              Rain   1        1.0                   15
#                        23   34           72               10                  4              Rain   1        1.0                   10
#            3   1       0    42           95               4                   16             Rain   0        1.0                    8
#                        1    42           95               4                   16             Rain   0        1.0                    3
#                        2    42           95               4                   16             Rain   0        1.0                    1
